# %% [markdown]
# # Import statements

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pylab import rcParams
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
#%reload_ext pycodestyle_magic
#%pycodestyle_on
#%pycodestyle_off

# %%
MAIN_FOLDER = 'c:/Users/champ/Python_proj/'
MWML_FOLDER = 'made_with_ml_repo/temp/moviebuddy/meta_data/'
FILE = "filtered.csv"


def prep_db(file, file_type):
    '''
    This module reads and prepares the db : cleans,
    deletes the columns with 'Unnamed' values,
    fills NaN values
    input :
    file # the movieset file
    file type # csv file type
    output :
    df # read movie set dataframe
    '''
    if file_type == 'csv':
        df = pd.read_csv(file, sep=';', dtype=str)  # Read CSV File
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df = df.fillna('')  # clean the data - get rid of NaN
    df = df.astype(str)  # change the default data type to string
    return(df)


movies = prep_db(MAIN_FOLDER + MWML_FOLDER + FILE, 'csv')

# %% [markdown]
# # Load movies

# %%
# movies = pd.read_csv("/content/drive/My Drive/MovieRecommender/filtered.csv", header=0, sep=';')
# movies = pd.read_csv("/content/drive/My Drive/MovieRecommender/filtered.csv", header=0, sep=';')
# movies = movies.replace({np.nan: None})

# %%
''' With previously used data given by MadewithML

# Load movies
movies = pd.read_csv("/content/drive/My Drive/MovieRecommender/filtered.csv", header=0, parse_dates=['date'])
movies = movies.replace({np.nan: None}) # replace NaN with None 

'''

# %% [markdown]
# # User defined functions

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %% [markdown]
# # EDA

# %%
movies.head()
# Out:
#        id                                  title tagline  \
# 0  460135  LEGO DC Super Hero Girls: Brain Drain
# 1  464207              The Truth Is in the Stars
# 2  463800                               Firebase
# 3  464111                                 Zygote
# 4  462108              Chris D'Elia: Man on Fire
#
#                                          description  \
# 0  When Supergirl, Wonder Woman, Batgirl, Bumbleb...
# 1  William Shatner sits down with scientists, inn...
# 2  Set during the Vietnam war, Firebase follows A...
# 3  Stranded in an Arctic mine, two survivors are ...
# 4  Unbridled comic Chris D'Elia reconsiders his a...
#
#                          genres                         keywords        date  \
# 0                     animation                  superhero, lego  2017-08-30
# 1                   documentary  nature, science, canadian movie  2017-05-01
# 2  action, science fiction, war               vietnam war, short  2017-06-28
# 3       horror, science fiction                                   2017-07-12
# 4                        comedy                  stand-up comedy  2017-06-27
#
#                        collection runtime revenue  ...        director  \
# 0  DC Super Hero Girls Collection     0.0     0.0  ...     Todd Grimes
# 1                                    86.0     0.0  ...  Craig Thompson
# 2                                    27.0     0.0  ...  Neill Blomkamp
# 3                                    23.0     0.0  ...  Neill Blomkamp
# 4                                    65.0     0.0  ...     Bill D'Elia
#
#                                                 cast    production_companies  \
# 0  Grey Griffin, Tara Strong, Anais Fairweather, ...  Warner Bros. Animation
# 1  William Shatner, Neil deGrasse Tyson, Chris Ha...
# 2  Steve Boyle, Nic Rhind, Robert Hobbs, Chris Wi...             Oats Studio
# 3                Dakota Fanning, Jose Pablo Cantillo             Oats Studio
# 4                                       Chris D'Elia
#
#        production_countries popularity average_vote num_votes language  \
# 0  United States of America   8.413734         10.0       2.0       en
# 1                    Canada   1.075249          7.5       2.0       en
# 2                    Canada   2.129137          7.3      28.0       en
# 3                    Canada   3.214001          7.2      28.0       en
# 4  United States of America   0.482896          5.8       6.0       en
#
#      imdb_id                        poster_url
# 0  tt7158814  /niLX2txdI5GlVowJlnb5Hr26QpK.jpg
# 1  tt7104950  /tqEtNlOmEAJKrJGGrkGMyLjfRrq.jpg
# 2  tt7078926  /e6qVOjp3QKHrA7k2sAbJSlDXkRM.jpg
# 3  tt7078780  /rjm7KaiLsEwRcxnlsaX9ryzzK1B.jpg
# 4  tt7068896  /dZgs1Ym7fe3fPxbeT5hq9XKLaDW.jpg
#
# [5 rows x 21 columns]

# %%
'''
# Function to display all rows and columns
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)
'''
# Out:
# '\n# Function to display all rows and columns\ndef display_all(df):\n    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): \n        display(df)\n'

# %%
display_all(movies.tail().T)
# Out:
#                                                                   45411  \
# id                                                               105158
# title                            Edison Kinetoscopic Record of a Sneeze
# tagline
# description           A man (Thomas Edison's assistant) takes a pinc...
# genres                                                      documentary
# keywords
# date                                                         1894-01-09
# collection
# runtime                                                             1.0
# revenue                                                             0.0
# budget                                                                0
# director                                          William K.L. Dickson
# cast                                                           Fred Ott
# production_companies                       Edison Manufacturing Company
# production_countries                           United States of America
# popularity                                                     0.312246
# average_vote                                                        4.7
# num_votes                                                          12.0
# language                                                             en
# imdb_id                                                       tt0000008
# poster_url                             /utsYe7NaVdiUhXpBwgln3LTucYs.jpg
#
#                                                                   45412  \
# id                                                                16624
# title                                                  Blacksmith Scene
# tagline
# description           Three men hammer on an anvil and pass a bottle...
# genres                                                            drama
# keywords                                      blacksmith, beer, workmen
# date                                                         1893-05-08
# collection
# runtime                                                             1.0
# revenue                                                             0.0
# budget                                                                0
# director                                          William K.L. Dickson
# cast                                           Charles Kayser, John Ott
# production_companies                       Edison Manufacturing Company
# production_countries                           United States of America
# popularity                                                     1.061591
# average_vote                                                        5.8
# num_votes                                                          19.0
# language                                                             xx
# imdb_id                                                       tt0000005
# poster_url                             /6nh4gdZ4cWQbnXDicWIGsOZiZsx.jpg
#
#                                                                   45413  \
# id                                                                88013
# title                                                      Poor Pierrot
# tagline
# description           One night, Arlequin come to see his lover Colo...
# genres                                                comedy, animation
# keywords                                                          short
# date                                                         1892-10-28
# collection
# runtime                                                             4.0
# revenue                                                             0.0
# budget                                                                0
# director                                                  Émile Reynaud
# cast
# production_companies
# production_countries                                             France
# popularity                                                     0.673164
# average_vote                                                        6.1
# num_votes                                                          19.0
# language                                                             fr
# imdb_id                                                       tt0000003
# poster_url                             /yCJr2zZqEbWLggyqumVcXBFQABf.jpg
#
#                                                                   45414  \
# id                                                                16612
# title                                                        Carmencita
# tagline
# description           The first woman to appear in front of an Ediso...
# genres                                                      documentary
# keywords                                            dancer, silent film
# date                                                         1894-03-14
# collection
# runtime                                                             1.0
# revenue                                                             0.0
# budget                                                                0
# director                                          William K.L. Dickson
# cast                                                         Carmencita
# production_companies                       Edison Manufacturing Company
# production_countries                           United States of America
# popularity                                                     1.273072
# average_vote                                                        4.9
# num_votes                                                          18.0
# language                                                             en
# imdb_id                                                       tt0000001
# poster_url                             /6QJowxF4f2hrUtmrDXOqbRDMdDH.jpg
#
#                                                                   45415
# id                                                                47116
# title                                                        The Winner
# tagline
# description           Tou former boxers meet in the ring again after...
# genres                                          drama, romance, foreign
# keywords
# date                                                         1979-03-09
# collection
# runtime                                                            78.0
# revenue                                                             0.0
# budget                                                                0
# director                                                  Dušan Trančík
# cast                  Jaroslav Tomsa, jaroslav pucher, Dagmar Kováči...
# production_companies
# production_countries
# popularity                                                          0.0
# average_vote                                                        0.0
# num_votes                                                           0.0
# language                                                             en
# imdb_id
# poster_url                             /yMCadbpPKxmYdkLdVpvsH0tPIwq.jpg

# %% [markdown]
# Observations:
# - Empty values in cell. Specifically,
#     - Some movies do not have taglines, keywords, date collection, revenue, budget, production companies.
# - Values in genre, keywords columns are stored as one string, needs to be split and stored as lists. (#Data cleaning1)

# %%
display_all(movies.describe(include='all').T)
# Out:
#                       count unique                       top   freq
# id                    45416  45416                     63065      1
# title                 45416  42264                Cinderella     11
# tagline               45416  20280                            25019
# description           45416  44292                              952
# genres                45416   4065                     drama   4996
# keywords              45416  25987                            14328
# date                  45416  17334                2008-01-01    136
# collection            45416   1694                            40930
# runtime               45416    354                      90.0   2555
# revenue               45416   6864                       0.0  38015
# budget                45416   1223                         0  36538
# director              45416  17568                              882
# cast                  45416  42668                             2409
# production_companies  45416  22667                            11861
# production_countries  45416   2390  United States of America  17838
# popularity            45416  43835                       0.0     65
# average_vote          45416     93                       0.0   2989
# num_votes             45416   1821                       1.0   3260
# language              45416     90                        en  32239
# imdb_id               45416  45416                 tt0120202      1
# poster_url            45416  45010                              381

# %%
movies.dtypes
# Out:
# id                      object
# title                   object
# tagline                 object
# description             object
# genres                  object
# keywords                object
# date                    object
# collection              object
# runtime                 object
# revenue                 object
# budget                  object
# director                object
# cast                    object
# production_companies    object
# production_countries    object
# popularity              object
# average_vote            object
# num_votes               object
# language                object
# imdb_id                 object
# poster_url              object
# dtype: object

# %% [markdown]
# #User profile

# %%
movies.shape
# Out:
# (45416, 21)

# %%
movies_subset = movies.dropna(subset=['keywords'])
movies_subset = movies_subset.reset_index(drop=True)

# %%
movies_subset.head(10)
# Out:
#        id                                          title tagline  \
# 0  460135          LEGO DC Super Hero Girls: Brain Drain
# 1  464207                      The Truth Is in the Stars
# 2  463800                                       Firebase
# 3  464111                                         Zygote
# 4  462108                      Chris D'Elia: Man on Fire
# 5  461634  Rory Scovel Tries Stand-Up for the First Time
# 6  461955                                          Rakka
# 7  460822                         Oh, Hello: On Broadway
# 8  461257                                       Queerama
# 9  457470          Site Unseen: An Emma Fielding Mystery
#
#                                          description  \
# 0  When Supergirl, Wonder Woman, Batgirl, Bumbleb...
# 1  William Shatner sits down with scientists, inn...
# 2  Set during the Vietnam war, Firebase follows A...
# 3  Stranded in an Arctic mine, two survivors are ...
# 4  Unbridled comic Chris D'Elia reconsiders his a...
# 5  Comedian Rory Scovel storms the stage in Atlan...
# 6  "Rakka" is the story of broken humanity follow...
# 7  Two delusional geriatrics reveal curious pasts...
# 8  50 years after decriminalisation of homosexual...
# 9  Brilliant, dedicated, and driven, archaeologis...
#
#                          genres                                 keywords  \
# 0                     animation                          superhero, lego
# 1                   documentary          nature, science, canadian movie
# 2  action, science fiction, war                       vietnam war, short
# 3       horror, science fiction
# 4                        comedy                          stand-up comedy
# 5                        comedy                          stand-up comedy
# 6       action, science fiction  digital film, film, short, experimental
# 7                        comedy                                 broadway
# 8
# 9                       mystery
#
#          date                      collection runtime revenue  ...  \
# 0  2017-08-30  DC Super Hero Girls Collection     0.0     0.0  ...
# 1  2017-05-01                                    86.0     0.0  ...
# 2  2017-06-28                                    27.0     0.0  ...
# 3  2017-07-12                                    23.0     0.0  ...
# 4  2017-06-27                                    65.0     0.0  ...
# 5  2017-06-20                                    66.0     0.0  ...
# 6  2017-06-14                                    22.0     0.0  ...
# 7  2017-06-13                                   102.0     0.0  ...
# 8  2017-06-09                                    75.0     0.0  ...
# 9  2017-06-04                                    90.0     0.0  ...
#
#               director                                               cast  \
# 0          Todd Grimes  Grey Griffin, Tara Strong, Anais Fairweather, ...
# 1       Craig Thompson  William Shatner, Neil deGrasse Tyson, Chris Ha...
# 2       Neill Blomkamp  Steve Boyle, Nic Rhind, Robert Hobbs, Chris Wi...
# 3       Neill Blomkamp                Dakota Fanning, Jose Pablo Cantillo
# 4          Bill D'Elia                                       Chris D'Elia
# 5          Scott Moran                                        Rory Scovel
# 6       Neill Blomkamp  Sigourney Weaver, Eugene Khumbanyiwa, Robert H...
# 7  Michael John Warren  Nick Kroll, John Mulaney, Steve Martin, Matthe...
# 8        Daisy Asquith
# 9         Douglas Barr  Courtney Thorne-Smith, James Tupper, Adam DiMa...
#
#      production_companies      production_countries popularity average_vote  \
# 0  Warner Bros. Animation  United States of America   8.413734         10.0
# 1                                            Canada   1.075249          7.5
# 2             Oats Studio                    Canada   2.129137          7.3
# 3             Oats Studio                    Canada   3.214001          7.2
# 4                          United States of America   0.482896          5.8
# 5                 Netflix  United States of America   0.593041          8.0
# 6             Oats Studio                    Canada   2.569474          7.4
# 7           Radical Media  United States of America   1.208618          6.8
# 8                                    United Kingdom   0.163015          0.0
# 9      Muse Entertainment  United States of America    0.86016          6.0
#
#   num_votes language    imdb_id                        poster_url
# 0       2.0       en  tt7158814  /niLX2txdI5GlVowJlnb5Hr26QpK.jpg
# 1       2.0       en  tt7104950  /tqEtNlOmEAJKrJGGrkGMyLjfRrq.jpg
# 2      28.0       en  tt7078926  /e6qVOjp3QKHrA7k2sAbJSlDXkRM.jpg
# 3      28.0       en  tt7078780  /rjm7KaiLsEwRcxnlsaX9ryzzK1B.jpg
# 4       6.0       en  tt7068896  /dZgs1Ym7fe3fPxbeT5hq9XKLaDW.jpg
# 5       6.0       en  tt7044010  /z4ppR4BpnXUQhIDIvQKTq0pAi6Z.jpg
# 6      44.0       en  tt6990734  /4wVeP9BHsQul7CRgdrfiUt1Rds1.jpg
# 7      13.0       en  tt6987652  /4sgAcBkhKoazB4xFwiYfWIdLMNf.jpg
# 8       0.0       en  tt6980792  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
# 9       2.0       en  tt6973942  /iqO9ITNYfTHafJ8e1Y4buZ1Vfzp.jpg
#
# [10 rows x 21 columns]

# %%
print(movies.shape)
print(movies_subset.shape)
# Out:
# (45416, 21)
# (45416, 21)

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(movies_subset.keywords)

# %%
tfidf_np_matrix = tfidf_matrix.toarray()

# %%
tfidf_np_matrix.shape
# Out:
# (45416, 12595)

# %%
tfidf_np_matrix[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
indices = pd.Series(movies_subset.title)
indices[:5]
# Out:
# 0    LEGO DC Super Hero Girls: Brain Drain
# 1                The Truth Is in the Stars
# 2                                 Firebase
# 3                                   Zygote
# 4                Chris D'Elia: Man on Fire
# Name: title, dtype: object

# %%
def recommendations(titles, tfidf_np_matrix=tfidf_np_matrix):
  
    idx = []
    recommended_movies=[]

    for title in titles:
        idx.append(indices[indices==title].index[0])
    print(idx)
    user_pref_vector = tfidf_np_matrix[idx].mean(axis=0)
    print(user_pref_vector )
    cosine_sim = cosine_similarity(tfidf_matrix,np.atleast_2d(user_pref_vector))
    df_cosine_sim = pd.DataFrame(cosine_sim,columns=['sim_score'])
    df_cosine_sim = df_cosine_sim.sort_values(by='sim_score',ascending=False)
    print(df_cosine_sim.head(20))
    top_10_indexes = list(df_cosine_sim.iloc[0:(10+len(titles))].index)
    print(top_10_indexes)
    for n,i in enumerate(top_10_indexes):
        if n < len(titles):
            continue
        recommended_movies.append([movies_subset.title.iloc[i],
                                   movies_subset.genres.iloc[i],
                                   movies_subset.keywords.iloc[i],
                                   movies_subset.popularity.iloc[i],
                                   movies_subset.average_vote.iloc[i],
                                   movies_subset.num_votes.iloc[i],
                                   df_cosine_sim.sim_score.iloc[n]])

    return pd.DataFrame(recommended_movies,columns=['movie_title','genres','keywords','popularity','average_vote','num_votes','cosine_score'])

# %%
def recommendations(titles, tfidf_np_matrix=tfidf_np_matrix):
    idx = []
    recommended_movies = []

    for title in titles:
        idx.append(indices[indices == title].index[0])
    print(idx)
    user_pref_vector = tfidf_np_matrix[idx].mean(axis=0)
    print(user_pref_vector)
    cosine_sim = cosine_similarity(tfidf_matrix,
                                   np.atleast_2d(user_pref_vector))
    df_cosine_sim = pd.DataFrame(cosine_sim, columns=['sim_score'])
    df_cosine_sim = df_cosine_sim.sort_values(by='sim_score', ascending=False)
    print(df_cosine_sim.head(20))
    top_10_indexes = list(df_cosine_sim.iloc[0:(10+len(titles))].index)
    print(top_10_indexes)
    for n, i in enumerate(top_10_indexes):
        if n < len(titles):
            continue
        recommended_movies.append([movies_subset.title.iloc[i],
                                   movies_subset.genres.iloc[i],
                                   movies_subset.keywords.iloc[i],
                                   movies_subset.popularity.iloc[i],
                                   movies_subset.average_vote.iloc[i],
                                   movies_subset.num_votes.iloc[i],
                                   df_cosine_sim.sim_score.iloc[n]])

    return pd.DataFrame(recommended_movies, columns=['movie_title',
                                                     'genres',
                                                     'keywords',
                                                     'popularity',
                                                     'average_vote',
                                                     'num_votes',
                                                     'cosine_score'])

# %%
recommendations(['Toy Story', 'The Dark Knight','The Dark Knight Rises','Ace Ventura: When Nature Calls'], tfidf_np_matrix=tfidf_np_matrix)
# Out:
# [28363, 7021, 12632, 28875]
# [0. 0. 0. ... 0. 0. 0.]
#        sim_score
# 28875   0.577350
# 12632   0.577350
# 28363   0.577350
# 3610    0.355135
# 11748   0.354092
# 26861   0.326043
# 36387   0.309664
# 27473   0.303791
# 18901   0.302014
# 32227   0.287942
# 21757   0.279752
# 29951   0.271053
# 20842   0.264049
# 31837   0.263899
# 18065   0.255984
# 32367   0.241639
# 10970   0.241020
# 10265   0.239702
# 40233   0.236827
# 31048   0.236061
# [28875, 12632, 28363, 3610, 11748, 26861, 36387, 27473, 18901, 32227, 21757, 29951, 20842, 31837]
#                        movie_title  \
# 0  Barbie and the Three Musketeers
# 1                   Small Soldiers
# 2     Animals Are Beautiful People
# 3                     Home Alone 3
# 4                      Toy Story 3
# 5                            Dolls
# 6             Young Black Stallion
# 7                             Toys
# 8                   Father and Son
# 9                     Child's Play
#
#                                               genres  \
# 0                                  animation, family
# 1  comedy, adventure, fantasy, science fiction, a...
# 2                        comedy, documentary, family
# 3                                     comedy, family
# 4                          animation, family, comedy
# 5                                    fantasy, horror
# 6                           adventure, drama, family
# 7                   fantasy, comedy, science fiction
# 8                                              drama
# 9                                   horror, thriller
#
#                                             keywords          popularity  \
# 0                                       based on toy   6.670164999999999
# 1  defense industry, toy shop, technical toy, sol...            10.03936
# 2                                     africa, animal  1.5821319999999999
# 3  parent child relationship, burglar, child hero...             8.04209
# 4  hostage, college, toy, barbie, animation, esca...            16.96647
# 5                  toy, gore, storm, doll, toy maker            4.545885
# 6  world war ii, human animal relationship, horse...            1.269123
# 7  brother brother relationship, loss of brother,...            5.923774
# 8                                 human relationship            1.559697
# 9  gun, birthday, voodoo, toy, stalker, murder, b...  19.827545999999998
#
#   average_vote num_votes  cosine_score
# 0          6.2      81.0      0.354092
# 1          6.2     522.0      0.326043
# 2          7.5      21.0      0.309664
# 3          5.1     632.0      0.303791
# 4          7.6    4710.0      0.302014
# 5          6.1      80.0      0.287942
# 6          5.4      18.0      0.279752
# 7          5.0     173.0      0.271053
# 8          5.0      10.0      0.264049
# 9          6.3     605.0      0.263899

# %%
movies_subset[movies_subset.title.str.contains('Ace Ventura',case=False)==True]
# Out:
#        id  ...                        poster_url
# 17   9273  ...  /wRlGnJhEzcxBjvWtvbjhDSU1cIY.jpg
# 297  3049  ...  /nZirljb8XYbKTWsRQTplDGhx39Q.jpg
#
# [2 rows x 21 columns]
