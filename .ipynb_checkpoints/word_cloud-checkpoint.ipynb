# %% [markdown]
# # Function definitions

# %%
def prep_db(file,file_type):
    '''
    This module reads and prepares the db : cleans,
    deletes the columns with 'Unnamed' values,
    fills NaN values
    input : 
    file # the movieset file
    file type # csv file type
    output :
    df # read movie set dataframe 
    '''
    if file_type == 'csv':
        df = pd.read_csv(file, sep=';', dtype=str) # Read CSV File    
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df = df.fillna('') # clean the data - get rid of NaN
    df = df.astype(str) # change the default data type to string
    return(df)

def combine_row_text(features,df):
    '''
    This module combines text columns and sets the case of the combined text to lower
    args :
    input : 
    features # list of database columns to search in the movies database
    df # pandas dataframe
    output : counts # dataframe
    '''
    df['comb'] = ''
    for feature  in features:
        df['comb']= df['comb'].str.cat(df[feature].copy(), sep =',')
    df['comb'] = df['comb'].str.lower()
    return(df)

def highest_count_words(df):
    '''
    This module takes as input the imported movie dataset 
    and counts the occurance of the words and
    sets the columns in decreasing order
    args :
    input : df # pandas dataframe of the imported movie dataset
    output : counts # dataframe of the counted words
    '''
    
    count_matrix = vectorizer.fit_transform(df.keywords)
    count_matrix = count_matrix.astype(np.int32)
    counts = pd.DataFrame(count_matrix.toarray(),
                      index=df.title,
                      columns=vectorizer.get_feature_names())
    return(counts)

def find_delete_columns(counts,character,char): 
    '''
    This module is run off of the delete columns mega
    and deletes the unwanted columns of words
    args :
    input : 
    counts # dataframe of column of counted words
    character # regex code for the particular character(s)
    char # the unwanted character(s) that I want deleted
    output :
    counts # dataframe without the unwanted characters
    '''
    t = 0 # column counter
    n = 1
    orig = len(counts.columns)
    #print(' ')
    #print(' ')
    #print(f'Original column count is {len(counts.columns)}')
    print(f'removing {char} .... ')
    for i in counts.columns:
        if t == (n * 1000):
            # print(str(round(t/len(counts.columns)*100,0))+'%')
            n +=1
        t+=1
        if re.findall(character, i):
            del counts[i]
    #print(f'after deleting the unwanted word -{char}-, the list is {len(counts.columns)} long')
    #print(f'Reduction effectiveness : {str(round((1-(len(counts.columns)/orig))*100,0))} %')
    return(counts)

def delete_columns_mega(counts):                   
    '''
    This module calls the sub module and controls the deletion of unwanted columns
    input : 
    counts # dataframe of column of counted words
    output :
    counts # dataframe without the unwanted characters    
    '''
    counts = find_delete_columns(counts, '\d', 'any numeric')
    counts = find_delete_columns(counts, '[\uac00-\ud7a3]', 'Korean characters')
    counts = find_delete_columns(counts, '[\u4e00-\u9FFF]', 'Chinese characters')
    counts = find_delete_columns(counts, '[\u0900-\u097F]',' Indian characters')
    counts = find_delete_columns(counts, '[\u0627-\u064a]',' Arabic characters')
    counts = find_delete_columns(counts, '[\u0400-\u04FF]',' Russian characters')
    counts = find_delete_columns(counts, '[\u0370-\u03FF]',' Greek characters')
    counts = find_delete_columns(counts, '[\u3040-\u30FF]',' Japanese Katagana characters')
    counts = find_delete_columns(counts, '[\u3040-\u309F]',' Japanese Hiragana characters')
    counts = find_delete_columns(counts, '[\u3040-\u30FF]',' Japanese Katagana characters')
#     counts = find_delete_columns(counts, '(^has$)',' has')
#     counts = find_delete_columns(counts, '(^time$)',' time')
#     counts = find_delete_columns(counts, '(^never$)',' never')
#     counts = find_delete_columns(counts, '(^director$)',' director')
#     counts = find_delete_columns(counts, '(^john$)',' john')
#     counts = find_delete_columns(counts, '(^and$)',' and')
#     counts = find_delete_columns(counts, '(^will$)',' will')
#     counts = find_delete_columns(counts, '(^you$)',' you')
#     counts = find_delete_columns(counts, '(^they$)',' they')
#     counts = find_delete_columns(counts, '(^is$)',' is')
#     counts = find_delete_columns(counts, '(^film$)',' film')
#     counts = find_delete_columns(counts, '(^it$)',' it')
#     counts = find_delete_columns(counts, '(^one$)',' one')
#     counts = find_delete_columns(counts, '(^its-?$)',' it,its')
#     counts = find_delete_columns(counts, '(^of$)',' of')
#     counts = find_delete_columns(counts, '(^on$)',' on')
#     counts = find_delete_columns(counts, '(^for$)',' for')
#     counts = find_delete_columns(counts, '(^the$)',' the')
#     counts = find_delete_columns(counts, '(^to$)',' to')
#     counts = find_delete_columns(counts, '(^your-?$)',' you,your')
#     counts = find_delete_columns(counts, '(^new$)',' new')
#     counts = find_delete_columns(counts, '(^man$)',' man')
#     counts = find_delete_columns(counts, '(^woman$)',' woman')
#     counts = find_delete_columns(counts, '(^no$)',' no')
#     counts = find_delete_columns(counts, '(^his$)',' his')
#     counts = find_delete_columns(counts, '(^he$)',' he')
#     counts = find_delete_columns(counts, '(^hers$)',' hers')
#     counts = find_delete_columns(counts, '(^can$)',' can')
#     counts = find_delete_columns(counts, '(^all$)',' all')
#     counts = find_delete_columns(counts, '(^from$)',' from')
#     counts = find_delete_columns(counts, '(^are$)',' are')
#     counts = find_delete_columns(counts, '(^there$)',' there')
#     counts = find_delete_columns(counts, '(^an$)',' an')
#     counts = find_delete_columns(counts, '(^with$)',' with')
#     counts = find_delete_columns(counts, '(^in$)',' in')
#     counts = find_delete_columns(counts, '(^be$)',' be')
#     counts = find_delete_columns(counts, '(^what$)',' what')
    return (counts)

def most_frequent_words(counts):
    '''
    This module prepares the most frequent words of the 
    specific movie's selection types and ouputs to a csv
    input : 
    counts # dataframe of column of counted words
    output :
    counts_transposed # column transferred to rows
    and saved to a csv
    '''
    counts_transposed = counts.T
    counts_transposed['sum'] = counts_transposed.sum(axis=1)
    cols = counts_transposed.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    counts_transposed = counts_transposed.astype(np.int32)
    counts_transposed = counts_transposed[cols]
    counts_transposed = counts_transposed.sort_values(by=['sum'], axis=0, ascending=False)
    movie_counts = counts_transposed
    most_frequent_words = counts_transposed[['sum']]
    most_frequent_words = most_frequent_words.reset_index()
    most_frequent_words = most_frequent_words.rename(columns={'index': 'word', 'sum':'frequency'}, index={'title': 'index'})
    return(most_frequent_words,counts_transposed)

def cloud_word(word,nr_of_movies,movie_counts):
    var = word
    df = movie_counts.T[[var]]
    return(df.sort_values(var, ascending=False).head(nr_of_movies))

def make_pandas(freq_words,nr_of_movies,movie_counts):
    '''
    '''
    word_list = freq_words['word']
    word_list = word_list.tolist()
    t = 0
    for i in word_list:
        movies = cloud_word(i,nr_of_movies,movie_counts)
        movies = movies[1:]
        movies = movies.reset_index()
        movies = pd.DataFrame(data=movies)
        movies = movies.rename(columns={'title':i})
        movies = movies.iloc[:, :-1]
        if t == 0:
            df1 = movies
        elif t> 1:
            df1 = pd.concat([df1,movies],axis=1)
        t+=1
    return(df1)
        
def word_cloud(wrds):
    '''
    The function is the word cloud generator
    Input : colunms of title and keywords of words and
    groups of words from the db.
    Output : the word cloud graphic 
    '''
    print(wrds)
    stopwords = set(STOPWORDS)
    
    wordcloud = WordCloud(width = 500, height = 500, 
                    background_color ='white', 
                    stopwords = stopwords,
                    random_state = None,
                    min_font_size = 15).generate(','.join(wrds)) 
    # plot the WordCloud image                        
    plt.figure(figsize = (10, 10), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off")
    plt.savefig(MAIN_FOLDER + MWML_FOLDER + 'word_cloud_graphic.png')
    plt.tight_layout(pad = 0) 
    plt.show()

# %% [markdown]
# # Import and main functions

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pathlib
import requests
import re
import psutil
#import openpyxl

vectorizer = CountVectorizer(stop_words='english')
'''
Imports the 44,000 movie database into a pandas df so you can retrieve the columns.
There are 24 columns in the database ranging from keywords to director.
'''
# Load the dataframe
MAIN_FOLDER = 'c:/Users/champ/Python_proj/'
MWML_FOLDER = 'made_with_ml_repo/temp/moviebuddy/meta_data/'
#FILE = "movies_database_cleaned_from_made_with_ml.csv"
FILE = "filtered.csv"

df = prep_db(MAIN_FOLDER + MWML_FOLDER + FILE,'csv')
#df = df[['title', 'director', 'tagline', 'genres', 'keywords']]
df = df[['title','keywords']]

#df = df.head(38000)
df['keywords'] = df['keywords'].str.replace(', ', ',')
df['keywords'] = df['keywords'].str.replace('\s', '_')
print('The selection types are : ')
print(df.info())

print(f'RAM = {psutil.virtual_memory().percent}')

# Main functions
counts = highest_count_words(df) # counts all the individual words in the title and the keywords
frequent_words,movie_counts = most_frequent_words(counts) # organizes the word count
print(display(frequent_words.head(10)))
movies = make_pandas(freq_words = frequent_words.head(50),nr_of_movies = 20,movie_counts = movie_counts)
movies.to_csv (MAIN_FOLDER + MWML_FOLDER + 'word_cloud_movie_recommendations.csv', index = False, header=True, sep=';')

# # This function cleans the database of unwanted words like "the" , "an" , other misc lanaguage characters, etc)  
# counts = delete_columns_mega(counts)
# Out:
# The selection types are :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45416 entries, 0 to 45415
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     45416 non-null  object
#  1   keywords  45416 non-null  object
# dtypes: object(2)
# memory usage: 709.8+ KB
# None
# RAM = 78.0
# title              word  frequency
# 0        woman_director       3038
# 1      independent_film       1914
# 2                murder       1285
# 3        based_on_novel        822
# 4               musical        726
# 5                   sex        684
# 6              violence        647
# 7                nudity        629
# 8               revenge        618
# 9             biography        613
# None

# %% [markdown]
# # Word cloud

# %%
'''
A word cloud is generated here based on the occurance of keyword words
'''
#word_cloud(df['keywords'])
word_cloud(df['keywords'])
# Out:
# 0                       superhero,lego
# 1        nature,science,canadian_movie
# 2                    vietnam_war,short
# 3
# 4                      stand-up_comedy
#                      ...
# 45411
# 45412          blacksmith,beer,workmen
# 45413                            short
# 45414               dancer,silent_film
# 45415
# Name: keywords, Length: 45416, dtype: object

# %%
movies
# Out:
#                                woman_director                    murder  \
# 0                              Advanced Style              The Revenant
# 1                                       Elegy                 Blindside
# 2                                 The Falling                   Martyrs
# 3                                   Bluebeard                Road Games
# 4                               Men with Guns                  Wreckage
# 5                                 Double Dare        The Boys Next Door
# 6                               Men with Guns               BreadCrumbs
# 7              In the Land of Blood and Honey                   Bullies
# 8                        Eila, Rampe ja Likka          Anything for Her
# 9                              A Crush on You                 Frequency
# 10                               Summer Night             Drowning Mona
# 11                 The Babushkas of Chernobyl         Late Night Trains
# 12  Aileen: Life and Death of a Serial Killer                     Cobra
# 13                               One Last Hug  I Even Met Happy Gypsies
# 14                             Les Misérables                    Mother
# 15                                     Suzaku        Young and Innocent
# 16                             Singapore GaGa                 Ned Rifle
# 17                            A Second Chance             Mumbai Police
# 18                   Coming Down The Mountain             Borrowed Time
#
#                     based_on_novel  \
# 0                         Disgrace
# 1                        Moby Dick
# 2         The Time Traveler's Wife
# 3   Invasion of the Body Snatchers
# 4                   Gone Baby Gone
# 5                    The Great Man
# 6                         The Lost
# 7                         Backlash
# 8                        Aparajito
# 9                             1984
# 10                 Floating Clouds
# 11                          Eragon
# 12                       The Shack
# 13                        Bambi II
# 14                       Rose Hill
# 15                       Insurgent
# 16                       Stray Dog
# 17                  The Dressmaker
# 18                     Citizen Dog
#
#                                              musical  \
# 0                               The Three Musketeers
# 1                                     Into the Woods
# 2                                    Sleeping Beauty
# 3                                    Sleeping Beauty
# 4                               The Three Musketeers
# 5                                       Stingray Sam
# 6                                             Frozen
# 7                                               Kiki
# 8                                      A Chorus Line
# 9                                           The Lure
# 10                                      Bran Nue Dae
# 11                               Comedian Harmonists
# 12                                    Sound of Noise
# 13                                     Take the Lead
# 14                                        Cinderella
# 15                                    Into the Woods
# 16                                   The Singing Nun
# 17  The Adventures of Priscilla, Queen of the Desert
# 18                                   The Tender Trap
#
#                                 sex                              violence  \
# 0                       Love Object                            Fatal Bond
# 1                            Edmond                        A Serbian Film
# 2             Dangerous Invitations                     A Deadly Adoption
# 3                                FM                          The Revenant
# 4                 The Boy Next Door                              No Mercy
# 5            Dream for an Insomniac                            Sexy Beast
# 6              The Invisible Maniac                                Edmond
# 7                        Trash Fire                              Cut Bank
# 8                           Eugenie                                Looper
# 9   Cheech & Chong's Animated Movie  Stray Cat Rock: Delinquent Girl Boss
# 10                             Rent                   Landmine Goes Click
# 11                            Lorna                    The Purge: Anarchy
# 12                      Last Summer                           Untraceable
# 13           There's Always Vanilla                            Dallas 362
# 14                 Lake Consequence                                 Juice
# 15                           Thirst                        Wheels of Fire
# 16                   Candy Stripers                        Summer's Blood
# 17                 The Late Bloomer                             The Chase
# 18                    First Desires             Once Upon a Time Veronica
#
#                                                nudity  \
# 0                                       Happy Campers
# 1                                       Summer Lovers
# 2                                           The Doors
# 3                                          Psycho III
# 4                                            Arachnia
# 5                                          Last Night
# 6                                            Fortress
# 7                                     Into the Forest
# 8                                         Cabin Fever
# 9          Things You Can Tell Just by Looking at Her
# 10                                                Up!
# 11                                             Schizo
# 12                                     Owning Mahowny
# 13                                    Above Suspicion
# 14                                      Promised Land
# 15                                            The Key
# 16                                               Love
# 17                               Flashbacks of a Fool
# 18  Schoolgirl Report Part 4: What Drives Parents ...
#
#                                           revenge  \
# 0                                         Shutter
# 1   In the Name of the King: A Dungeon Siege Tale
# 2                                        Bastards
# 3                                T2 Trainspotting
# 4                                          Hamlet
# 5                              Heaven's Prisoners
# 6                                        Raw Edge
# 7                                         Altered
# 8                              A Bittersweet Life
# 9                                       Moby Dick
# 10                                   The Outsider
# 11                            The Killer Is Loose
# 12                           John Tucker Must Die
# 13                                       Bastards
# 14                             Indestructible Man
# 15                                  The Equalizer
# 16                              The Hunting Party
# 17                                      Furious 7
# 18                                       Bastards
#
#                         biography                                 suspense  \
# 0                         Greater                               Dead Again
# 1               Against the Ropes                          Above Suspicion
# 2                            Life                        The Boy Next Door
# 3                       Christine                               True Crime
# 4                       Malcolm X                                     4bia
# 5                          Loving                                 Deceived
# 6   Orson Welles: Shadows & Light                            The Phone Box
# 7                  Temple Grandin                                   Asylum
# 8                         Endgame                                    11:59
# 9     The Philadelphia Experiment                           Down the Shore
# 10          Sex, Drugs & Taxation                           Death Sentence
# 11                         Tracks                            A Simple Plan
# 12       Stuart: A Life Backwards                                Notorious
# 13                         Neruda                                 Gaslight
# 14                     Ludwig van  The Little Girl Who Lives Down the Lane
# 15                           Milk                               Road Games
# 16             Summer in February                      The Weight of Water
# 17            The Scarlet Empress                          As Good As Dead
# 18                  Young Cassidy                               La Cienaga
#
#     ...                     gay                     marriage  \
# 0   ...           Bad Education        Transistor Love Story
# 1   ...                 Esteros                     On Guard
# 2   ...                 Weekend                   Antichrist
# 3   ...   Make the Yuletide Gay                        Bliss
# 4   ...             The Phantom                Today We Live
# 5   ...               Mr. Right                War and Peace
# 6   ...               Tarnation                           RV
# 7   ...              Tumbledown              Pleasure Cruise
# 8   ...         Paternity Leave                Anna Karenina
# 9   ...  Norman... Is That You?                       Prague
# 10  ...         Velvet Goldmine                      Ex-Lady
# 11  ...         Parting Glances             I Give It a Year
# 12  ...             Boys Life 2            Life Is a Trumpet
# 13  ...                    Vito            I'll Cry Tomorrow
# 14  ...         Madagascar Skin      Ann Carver's Profession
# 15  ...              The String                  Plain Dirty
# 16  ...            Wittgenstein  The Legend of Sleepy Hollow
# 17  ...                Strapped                 Just Married
# 18  ...               Stonewall     The Time Traveler's Wife
#
#                           christmas  \
# 0                 Christmas on Mars
# 1                 A Christmas Carol
# 2                 A Christmas Carol
# 3                    Donovan's Reef
# 4             A Nanny for Christmas
# 5                          Cover Up
# 6                          Daylight
# 7                  A Christmas Kiss
# 8                       The Snowman
# 9   The Fitzgerald Family Christmas
# 10                            Elves
# 11                 Saving Christmas
# 12                Christmas Oranges
# 13         Santa Claus Is a Stinker
# 14         When Santa Fell to Earth
# 15                        Northpole
# 16                Jaws: The Revenge
# 17                      Santa Claus
# 18                   Running Scared
#
#                                             death  \
# 0                    The Legend of Paul and Paula
# 1                                 Waking the Dead
# 2                                      Wilderness
# 3                                    Toni Erdmann
# 4                                      Ten Canoes
# 5                                The Evening Star
# 6                                         Tum Bin
# 7                                        Drishyam
# 8                                        The Omen
# 9                           Manchester by the Sea
# 10                                   The Guardian
# 11                                       The Rift
# 12                                        Everest
# 13                                      Home Care
# 14                                    The Dentist
# 15                The Flower with Petals of Steel
# 16  The Last Will and Testament of Rosalind Leigh
# 17                                   The Guardian
# 18                            Struck by Lightning
#
#                         gangster                                        gore  \
# 0                   Black Friday                                        Xtro
# 1                    The General                                  Possession
# 2              A Bullet for Joey                           Texas Chainsaw 3D
# 3                The Ice Harvest                                     Altered
# 4                         Gloria                       The Windmill Massacre
# 5           The Evil That Men Do                                  The Ordeal
# 6                        Villain                                    13 Eerie
# 7                      Forbidden                                      Jack O
# 8                     Mickey One                                  GoodFellas
# 9                 Gangster Squad                        Flesh Eating Mothers
# 10                The Jerky Boys                                    Pandemic
# 11             His Kind of Woman                                    The Void
# 12                    The Hitman                                  In My Skin
# 13       Angels with Dirty Faces                                       Dolls
# 14                 Boiling Point  I Don't Feel at Home in This World Anymore
# 15  The Amazing Dr. Clitterhouse                                   Psycho II
# 16            Force of Execution                         The Grapes of Death
# 17                        Circus                            The Exterminator
# 18                   Bal-Can-Can                         The Hills Have Eyes
#
#                         zombie                small_town  \
# 0                 Patient Zero       Edward Scissorhands
# 1                     Trancers              Killer Movie
# 2     Resident Evil: Afterlife                Spellbound
# 3       Revenge of the Zombies            Only the Young
# 4                 Zombie Pizza            Bye Bye Birdie
# 5     Night of the Living Dead              Happy, Texas
# 6     Night of the Living Dead           Charley Varrick
# 7     Resident Evil: Damnation                Seedpeople
# 8                    Raw Force               The Killers
# 9                   Sugar Hill          The Vicious Kind
# 10                      Versus               The Crazies
# 11                    13 Eerie               The Discord
# 12             I Eat Your Skin            Summer Holiday
# 13           The Ghost Galleon                Manglehorn
# 14  Night of Something Strange         Miraklet i Viskan
# 15      Boo! A Madea Halloween             The Lost Boys
# 16     Blood of Ghastly Horror              Clay Pigeons
# 17   The Dead Hate the Living!  The Man Who Wasn't There
# 18       The Last Days on Mars         Beyond the Forest
#
#                                detective               london_england
# 0                                 Fallen               Pool of London
# 1                             The Caller                    Metroland
# 2                          The Medallion    We Still Kill the Old Way
# 3   The Living Dead at Manchester Morgue                Shooting Fish
# 4                                  Angel                   Mr. Holmes
# 5                      Shadow of a Doubt          Tomorrow Never Dies
# 6                                   Feed  The Man Who Knew Too Little
# 7                                Witness       Roald Dahl's Esio Trot
# 8                           Gang Related                    B. Monkey
# 9                          Hollywoodland                 Flushed Away
# 10       Butcher, Baker, Nightmare Maker             Imagine Me & You
# 11                 Beverly Hills Cop III      The Very Thought of You
# 12                Murder in a Small Town                 Stage Fright
# 13                   The New York Ripper                      Scandal
# 14                               Sisters            London Has Fallen
# 15                                 Angel                  Match Point
# 16                          Dead Silence              Broken Blossoms
# 17                         Secret Window                 Notting Hill
# 18                 Whistling in Brooklyn                      9 Songs
#
# [19 rows x 49 columns]

# %%
movie_counts
# Out:
# title              sum  tt7158814|LEGO DC Super Hero Girls: Brain Drain  \
# woman_director    3038                                                0
# independent_film  1914                                                0
# murder            1285                                                0
# based_on_novel     822                                                0
# musical            726                                                0
# ...                ...                                              ...
# jackalope            1                                                0
# jacobs_ladder        1                                                0
# jacques_prevert      1                                                0
# jade                 1                                                0
# 형사_duelist           1                                                0
#
# title             tt7104950|The Truth Is in the Stars  tt7078926|Firebase  \
# woman_director                                      0                   0
# independent_film                                    0                   0
# murder                                              0                   0
# based_on_novel                                      0                   0
# musical                                             0                   0
# ...                                               ...                 ...
# jackalope                                           0                   0
# jacobs_ladder                                       0                   0
# jacques_prevert                                     0                   0
# jade                                                0                   0
# 형사_duelist                                          0                   0
#
# title             tt7078780|Zygote  tt7068896|Chris D'Elia: Man on Fire  \
# woman_director                   0                                    0
# independent_film                 0                                    0
# murder                           0                                    0
# based_on_novel                   0                                    0
# musical                          0                                    0
# ...                            ...                                  ...
# jackalope                        0                                    0
# jacobs_ladder                    0                                    0
# jacques_prevert                  0                                    0
# jade                             0                                    0
# 형사_duelist                       0                                    0
#
# title             tt7044010|Rory Scovel Tries Stand-Up for the First Time  \
# woman_director                                                    0
# independent_film                                                  0
# murder                                                            0
# based_on_novel                                                    0
# musical                                                           0
# ...                                                             ...
# jackalope                                                         0
# jacobs_ladder                                                     0
# jacques_prevert                                                   0
# jade                                                              0
# 형사_duelist                                                        0
#
# title             tt6990734|Rakka  tt6987652|Oh, Hello: On Broadway  \
# woman_director                  0                                 0
# independent_film                0                                 0
# murder                          0                                 0
# based_on_novel                  0                                 0
# musical                         0                                 0
# ...                           ...                               ...
# jackalope                       0                                 0
# jacobs_ladder                   0                                 0
# jacques_prevert                 0                                 0
# jade                            0                                 0
# 형사_duelist                      0                                 0
#
# title             tt6980792|Queerama  ...  tt0000029|Baby's Meal  \
# woman_director                     0  ...                      0
# independent_film                   0  ...                      0
# murder                             0  ...                      0
# based_on_novel                     0  ...                      0
# musical                            0  ...                      0
# ...                              ...  ...                    ...
# jackalope                          0  ...                      0
# jacobs_ladder                      0  ...                      0
# jacques_prevert                    0  ...                      0
# jade                               0  ...                      0
# 형사_duelist                         0  ...                      0
#
# title             tt0000023|Baignade en Mer  \
# woman_director                            0
# independent_film                          0
# murder                                    0
# based_on_novel                            0
# musical                                   0
# ...                                     ...
# jackalope                                 0
# jacobs_ladder                             0
# jacques_prevert                           0
# jade                                      0
# 형사_duelist                                0
#
# title             tt0000014|Tables Turned on the Gardener  \
# woman_director                                          0
# independent_film                                        0
# murder                                                  0
# based_on_novel                                          0
# musical                                                 0
# ...                                                   ...
# jackalope                                               0
# jacobs_ladder                                           0
# jacques_prevert                                         0
# jade                                                    0
# 형사_duelist                                              0
#
# title             tt0000012|The Arrival of a Train at La Ciotat  \
# woman_director                                                0
# independent_film                                              0
# murder                                                        0
# based_on_novel                                                0
# musical                                                       0
# ...                                                         ...
# jackalope                                                     0
# jacobs_ladder                                                 0
# jacques_prevert                                               0
# jade                                                          0
# 형사_duelist                                                    0
#
# title             tt0000010|Workers Leaving the Lumière Factory  \
# woman_director                                                0
# independent_film                                              0
# murder                                                        0
# based_on_novel                                                0
# musical                                                       0
# ...                                                         ...
# jackalope                                                     0
# jacobs_ladder                                                 0
# jacques_prevert                                               0
# jade                                                          0
# 형사_duelist                                                    0
#
# title             tt0000008|Edison Kinetoscopic Record of a Sneeze  \
# woman_director                                                   0
# independent_film                                                 0
# murder                                                           0
# based_on_novel                                                   0
# musical                                                          0
# ...                                                            ...
# jackalope                                                        0
# jacobs_ladder                                                    0
# jacques_prevert                                                  0
# jade                                                             0
# 형사_duelist                                                       0
#
# title             tt0000005|Blacksmith Scene  tt0000003|Poor Pierrot  \
# woman_director                             0                       0
# independent_film                           0                       0
# murder                                     0                       0
# based_on_novel                             0                       0
# musical                                    0                       0
# ...                                      ...                     ...
# jackalope                                  0                       0
# jacobs_ladder                              0                       0
# jacques_prevert                            0                       0
# jade                                       0                       0
# 형사_duelist                                 0                       0
#
# title             tt0000001|Carmencita  0|The Winner
# woman_director                       0             0
# independent_film                     0             0
# murder                               0             0
# based_on_novel                       0             0
# musical                              0             0
# ...                                ...           ...
# jackalope                            0             0
# jacobs_ladder                        0             0
# jacques_prevert                      0             0
# jade                                 0             0
# 형사_duelist                           0             0
#
# [19971 rows x 45417 columns]
